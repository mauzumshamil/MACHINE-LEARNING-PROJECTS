# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/diamonds-null.csv")

# %%
df
# Out:
#        carat        cut color clarity  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   55.0   2757  5.83  5.87  3.64
#
#        price_new
# 0          163.0
# 1          163.0
# 2          163.5
# 3          167.0
# 4          167.5
# ...

# %%
df.head()
# Out:
#    carat      cut color clarity  table  price     x     y     z  price_new
# 0   0.23    Ideal     E     SI2   55.0    326  3.95  3.98  2.43      163.0
# 1   0.21  Premium     E     SI1   61.0    326  3.89  3.84  2.31      163.0
# 2   0.23     Good     E     VS1   65.0    327  4.05  4.07  2.31      163.5
# 3   0.29  Premium     I     VS2   58.0    334  4.20  4.23  2.63      167.0
# 4   0.31     Good     J     SI2   58.0    335  4.34  4.35  2.75      167.5

# %%
df
# Out:
#        carat        cut color clarity  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   55.0   2757  5.83  5.87  3.64
#
#        price_new
# 0          163.0
# 1          163.0
# 2          163.5
# 3          167.0
# 4          167.5
# ...

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'table', 'price', 'x', 'y', 'z',
#        'price_new'],
#       dtype='object')

# %% [markdown]
# # missing value

# %%
df.dtypes
# Out:
# carat        float64
# cut           object
# color         object
# clarity       object
# table        float64
# price          int64
# x            float64
# y            float64
# z            float64
# price_new    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# carat        99
# cut           0
# color        56
# clarity       0
# table        63
# price         0
# x             0
# y             0
# z             0
# price_new     0
# dtype: int64

# %% [markdown]
# carat and table are float so we check the histogram on them

# %%
# as for the color its object therefore its mode()[0]

df['color']=df['color'].fillna(df['color'].mode()[0])

# %%
plt.hist(df['carat'])

# its median because the graph have skewness
# Out:
# (array([2.5155e+04, 1.8527e+04, 7.1290e+03, 2.3490e+03, 6.1400e+02,
#         5.3000e+01, 6.0000e+00, 5.0000e+00, 2.0000e+00, 1.0000e+00]),
#  array([0.2  , 0.681, 1.162, 1.643, 2.124, 2.605, 3.086, 3.567, 4.048,
#         4.529, 5.01 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['table'])
#  its a mean as for the graph dont have skewness
# Out:
# (array([2.0000e+00, 6.5700e+02, 3.7491e+04, 1.5138e+04, 5.6300e+02,
#         2.3000e+01, 2.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([43. , 48.2, 53.4, 58.6, 63.8, 69. , 74.2, 79.4, 84.6, 89.8, 95. ]),
#  <BarContainer object of 10 artists>)

# %%
df['carat']=df['carat'].fillna(df['carat'].median())

# %%
df['table']=df['table'].fillna(df['table'].mean())

# %%
df.isna().sum()
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# table        0
# price        0
# x            0
# y            0
# z            0
# price_new    0
# dtype: int64

# %% [markdown]
# # outlier

# %%
df.head()
# Out:
#    carat      cut color clarity  table  price     x     y     z  price_new
# 0   0.23    Ideal     E     SI2   55.0    326  3.95  3.98  2.43      163.0
# 1   0.21  Premium     E     SI1   61.0    326  3.89  3.84  2.31      163.0
# 2   0.23     Good     E     VS1   65.0    327  4.05  4.07  2.31      163.5
# 3   0.29  Premium     I     VS2   58.0    334  4.20  4.23  2.63      167.0
# 4   0.31     Good     J     SI2   58.0    335  4.34  4.35  2.75      167.5

# %%
df.boxplot(color="green",figsize=(20,10))
# Out:
# <Axes: >

# %%
sns.boxplot(df['price_new'])
# Out:
# <Axes: ylabel='price_new'>

# %%
sns.boxplot(df['carat'])
# Out:
# <Axes: ylabel='carat'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   carat      53940 non-null  float64
#  1   cut        53940 non-null  object
#  2   color      53940 non-null  object
#  3   clarity    53940 non-null  object
#  4   table      53940 non-null  float64
#  5   price      53940 non-null  int64
#  6   x          53940 non-null  float64
#  7   y          53940 non-null  float64
#  8   z          53940 non-null  float64
#  9   price_new  53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# we are not doing outlier removal because it affect the data density

# %% [markdown]
# # encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df.head()
# Out:
#    carat      cut color clarity  table  price     x     y     z  price_new
# 0   0.23    Ideal     E     SI2   55.0    326  3.95  3.98  2.43      163.0
# 1   0.21  Premium     E     SI1   61.0    326  3.89  3.84  2.31      163.0
# 2   0.23     Good     E     VS1   65.0    327  4.05  4.07  2.31      163.5
# 3   0.29  Premium     I     VS2   58.0    334  4.20  4.23  2.63      167.0
# 4   0.31     Good     J     SI2   58.0    335  4.34  4.35  2.75      167.5

# %%
df.color.nunique()
# Out:
# 7

# %%
df.cut.nunique()
# Out:
# 5

# %%
df.clarity.nunique()
# Out:
# 8

# %%
for i in ['cut','clarity','color']:
  df[i]=le.fit_transform(df[i])
df[i]
# Out:
# 0        1
# 1        1
# 2        1
# 3        5
# 4        6
#         ..
# 53935    0
# 53936    0
# 53937    0
# 53938    4
# 53939    0
# Name: color, Length: 53940, dtype: int64

# %%
df.head()
# Out:
#    carat  cut  color  clarity  table  price     x     y     z  price_new
# 0   0.23    2      1        3   55.0    326  3.95  3.98  2.43      163.0
# 1   0.21    3      1        2   61.0    326  3.89  3.84  2.31      163.0
# 2   0.23    1      1        4   65.0    327  4.05  4.07  2.31      163.5
# 3   0.29    3      5        5   58.0    334  4.20  4.23  2.63      167.0
# 4   0.31    1      6        3   58.0    335  4.34  4.35  2.75      167.5

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()

# %%
df.head()
# Out:
#    carat  cut  color  clarity  table  price     x     y     z  price_new
# 0   0.23    2      1        3   55.0    326  3.95  3.98  2.43      163.0
# 1   0.21    3      1        2   61.0    326  3.89  3.84  2.31      163.0
# 2   0.23    1      1        4   65.0    327  4.05  4.07  2.31      163.5
# 3   0.29    3      5        5   58.0    334  4.20  4.23  2.63      167.0
# 4   0.31    1      6        3   58.0    335  4.34  4.35  2.75      167.5

# %%
x = df.drop(['cut','color','clarity','table'],axis=1)
x.head()
# Out:
#    carat  price     x     y     z  price_new
# 0   0.23    326  3.95  3.98  2.43      163.0
# 1   0.21    326  3.89  3.84  2.31      163.0
# 2   0.23    327  4.05  4.07  2.31      163.5
# 3   0.29    334  4.20  4.23  2.63      167.0
# 4   0.31    335  4.34  4.35  2.75      167.5

# %%
y = df.drop(['carat','x','y','z','price_new'],axis=1)

# %%
y.head()
# Out:
#    cut  color  clarity  table  price
# 0    2      1        3   55.0    326
# 1    3      1        2   61.0    326
# 2    1      1        4   65.0    327
# 3    3      5        5   58.0    334
# 4    1      6        3   58.0    335

# %%
x = minmax.fit_transform(x)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x
# Out:
# array([[6.23700624e-03, 0.00000000e+00, 3.67783985e-01, 6.75721562e-02,
#         7.64150943e-02, 0.00000000e+00],
#        [2.07900208e-03, 0.00000000e+00, 3.62197393e-01, 6.51952462e-02,
#         7.26415094e-02, 0.00000000e+00],
#        [6.23700624e-03, 5.40628210e-05, 3.77094972e-01, 6.91001698e-02,
#         7.26415094e-02, 5.40628210e-05],
#        ...,
#        [1.03950104e-01, 1.31426718e-01, 5.27001862e-01, 9.64346350e-02,
#         1.11949686e-01, 1.31426718e-01],
#        [1.37214137e-01, 1.31426718e-01, 5.72625698e-01, 1.03904924e-01,
#         1.17610063e-01, 1.31426718e-01],
#        [1.14345114e-01, 1.31426718e-01, 5.42830540e-01, 9.96604414e-02,
#         1.14465409e-01, 1.31426718e-01]])

# %%
new = pd.DataFrame(x,columns=['carat','price1','x','y','z','price_new'])

# %%
new.head()
# Out:
#       carat    price1         x         y         z  price_new
# 0  0.006237  0.000000  0.367784  0.067572  0.076415   0.000000
# 1  0.002079  0.000000  0.362197  0.065195  0.072642   0.000000
# 2  0.006237  0.000054  0.377095  0.069100  0.072642   0.000054
# 3  0.018711  0.000433  0.391061  0.071817  0.082704   0.000433
# 4  0.022869  0.000487  0.404097  0.073854  0.086478   0.000487

# %%
df = pd.concat([y,new],axis=1)

# %%
df
# Out:
#        cut  color  clarity  table  price     carat    price1         x  \
# 0        2      1        3   55.0    326  0.006237  0.000000  0.367784
# 1        3      1        2   61.0    326  0.002079  0.000000  0.362197
# 2        1      1        4   65.0    327  0.006237  0.000054  0.377095
# 3        3      5        5   58.0    334  0.018711  0.000433  0.391061
# 4        1      6        3   58.0    335  0.022869  0.000487  0.404097
# ...    ...    ...      ...    ...    ...       ...       ...       ...
# 53935    2      0        2   57.0   2757  0.108108  0.131427  0.535382
# 53936    1      0        2   55.0   2757  0.108108  0.131427  0.529795
# 53937    4      0        2   60.0   2757  0.103950  0.131427  0.527002
# 53938    3      4        3   58.0   2757  0.137214  0.131427  0.572626
# 53939    2      0        3   55.0   2757  0.114345  0.131427  0.542831
#
#               y         z  price_new
# 0      0.067572  0.076415   0.000000
# 1      0.065195  0.072642   0.000000
# ...

# %%
df.drop('price1',axis=1,inplace=True)

# %%
df.drop('price',axis=1,inplace=True)

# %% [markdown]
#  # regression model

# %%
df.head()
# Out:
#    cut  color  clarity  table     carat         x         y         z  \
# 0    2      1        3   55.0  0.006237  0.367784  0.067572  0.076415
# 1    3      1        2   61.0  0.002079  0.362197  0.065195  0.072642
# 2    1      1        4   65.0  0.006237  0.377095  0.069100  0.072642
# 3    3      5        5   58.0  0.018711  0.391061  0.071817  0.082704
# 4    1      6        3   58.0  0.022869  0.404097  0.073854  0.086478
#
#    price_new
# 0   0.000000
# 1   0.000000
# 2   0.000054
# 3   0.000433
# 4   0.000487

# %%
df.corr()
# Out:
#                 cut     color   clarity     table     carat         x  \
# cut        1.000000  0.000304  0.028235  0.150261  0.017124  0.022342
# color      0.000304  1.000000 -0.027795  0.026456  0.291437  0.270287
# clarity    0.028235 -0.027795  1.000000 -0.088242 -0.214290 -0.225721
# table      0.150261  0.026456 -0.088242  1.000000  0.181573  0.195337
# carat      0.017124  0.291437 -0.214290  0.181573  1.000000  0.975094
# x          0.022342  0.270287 -0.225721  0.195337  0.975094  1.000000
# y          0.027572  0.263584 -0.217616  0.183755  0.951722  0.974701
# z          0.002018  0.269496 -0.225894  0.151757  0.958047  0.975223
# price_new  0.039860  0.172511 -0.071535  0.127058  0.921591  0.884435
#
#                   y         z  price_new
# cut        0.027572  0.002018   0.039860
# color      0.263584  0.269496   0.172511
# clarity   -0.217616 -0.225894  -0.071535
# table      0.183755  0.151757   0.127058
# carat      0.951722  0.958047   0.921591
# ...

# %%
# splitting the dataframe into two dfs

x = df.drop('price_new',axis=1)
x1=pd.DataFrame(x)
print(x1)
y = df['price_new']
y1 = pd.DataFrame(y)
print(y1)
# Out:
#        cut  color  clarity  table     carat         x         y         z
# 0        2      1        3   55.0  0.006237  0.367784  0.067572  0.076415
# 1        3      1        2   61.0  0.002079  0.362197  0.065195  0.072642
# 2        1      1        4   65.0  0.006237  0.377095  0.069100  0.072642
# 3        3      5        5   58.0  0.018711  0.391061  0.071817  0.082704
# 4        1      6        3   58.0  0.022869  0.404097  0.073854  0.086478
# ...    ...    ...      ...    ...       ...       ...       ...       ...
# 53935    2      0        2   57.0  0.108108  0.535382  0.097793  0.110063
# 53936    1      0        2   55.0  0.108108  0.529795  0.097623  0.113522
# 53937    4      0        2   60.0  0.103950  0.527002  0.096435  0.111950
# 53938    3      4        3   58.0  0.137214  0.572626  0.103905  0.117610
# 53939    2      0        3   55.0  0.114345  0.542831  0.099660  0.114465
#
# [53940 rows x 8 columns]
#        price_new
# 0       0.000000
# 1       0.000000
# ...

# %%
# now we got x1 and y1

# %%
#we will split both variables into the test set and training set.
#We are splitting our dataset so that we can train our model using a training dataset and then test the model using a test dataset.

# Splitting the dataset into training and test set.

from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1,test_size=0.25,random_state=42)

# %%
# now we do the train and test on the datasets

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
# we called the library and created a instance

# %%
# creatin a model on the training set
model=lr.fit(x1_train,y1_train)

# %%
# now we use this model onto the test

# %%
y1_pred = model.predict(x1_test)

print(y1_pred)
# Out:
# [[-0.00056854]
#  [ 0.15740295]
#  [ 0.09865596]
#  ...
#  [ 0.4231857 ]
#  [ 0.27139916]
#  [ 0.26989037]]

# %%
print(y1_test)
# Out:
#        price_new
# 1388    0.012597
# 50052   0.101368
# 41645   0.049305
# 42377   0.052873
# 17244   0.355463
# ...          ...
# 36825   0.034114
# 24803   0.695302
# 20999   0.480564
# 8471    0.221117
# 4204    0.175055
#
# [13485 rows x 1 columns]

# %%
# now we can check the accuracy by two ways

# %%
# mean_squared_error

from sklearn.metrics import mean_squared_error
print('mse is:',mean_squared_error(y1_test,y1_pred))
# Out:
# mse is: 0.005312067048851201

# %%
# r2_score

from sklearn.metrics import r2_score
print("r2 score:",r2_score(y1_test,y1_pred))
# Out:
# r2 score: 0.8843092930614257
