# %%
import pandas as pd

# %%
#pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\mauzu\Downloads\brain_stroke.csv")

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
# 5    Male  74.0             1              1          Yes        Private
# 6  Female  69.0             0              0           No        Private
# 7  Female  78.0             0              0          Yes        Private
# 8  Female  81.0             1              0          Yes        Private
# 9  Female  61.0             0              1          Yes       Govt_job
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# ...

# %%
df.tail(10)
# Out:
#       gender    age  hypertension  heart_disease ever_married work_type  \
# 4971    Male  37.00             0              0          Yes   Private
# 4972    Male  72.00             0              1          Yes   Private
# 4973    Male   1.32             0              0           No  children
# 4974    Male  58.00             0              0          Yes  Govt_job
# 4975    Male  31.00             0              0           No   Private
# 4976    Male  41.00             0              0           No   Private
# 4977    Male  40.00             0              0          Yes   Private
# 4978  Female  45.00             1              0          Yes  Govt_job
# 4979    Male  40.00             0              0          Yes   Private
# 4980  Female  80.00             1              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 4971          Rural             107.06  29.7           smokes       0
# ...

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4981.000000   4981.000000    4981.000000        4981.000000
# mean     43.419859      0.096165       0.055210         105.943562
# std      22.662755      0.294848       0.228412          45.075373
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.230000
# 50%      45.000000      0.000000       0.000000          91.850000
# 75%      61.000000      0.000000       0.000000         113.860000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4981.000000  4981.000000
# mean     28.498173     0.049789
# std       6.790464     0.217531
# min      14.000000     0.000000
# 25%      23.700000     0.000000
# 50%      28.100000     0.000000
# 75%      32.600000     0.000000
# max      48.900000     1.000000

# %%
df.isna().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df.nunique()
# Out:
# gender                  2
# age                   104
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               4
# Residence_type          2
# avg_glucose_level    3895
# bmi                   342
# smoking_status          4
# stroke                  2
# dtype: int64

# %%
plt.boxplot(df['bmi'])
plt.show()

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# label encoding

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
from sklearn.preprocessing import LabelEncoder
Le = LabelEncoder()

# %%
for i in ['ever_married','work_type','Residence_type','smoking_status']:
    df[i] = Le.fit_transform(df[i])

# %%
df[i]
# Out:
# 0       1
# 1       2
# 2       3
# 3       2
# 4       1
#        ..
# 4976    1
# 4977    3
# 4978    3
# 4979    3
# 4980    2
# Name: smoking_status, Length: 4981, dtype: int64

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0    Male  67.0             0              1             1          1
# 1    Male  80.0             0              1             1          1
# 2  Female  49.0             0              0             1          1
# 3  Female  79.0             1              0             1          2
# 4    Male  81.0             0              0             1          1
#
#    Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0               1             228.69  36.6               1       1
# 1               0             105.92  32.5               2       1
# 2               1             171.23  34.4               3       1
# 3               0             174.12  24.0               2       1
# 4               1             186.21  29.0               1       1

# %%
df['gender'] = Le.fit_transform(df['gender'])

# %%
df.head(3)
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  67.0             0              1             1          1
# 1       1  80.0             0              1             1          1
# 2       0  49.0             0              0             1          1
#
#    Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0               1             228.69  36.6               1       1
# 1               0             105.92  32.5               2       1
# 2               1             171.23  34.4               3       1

# %% [markdown]
# minmax scaling

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
x = df.drop(['avg_glucose_level','bmi'],axis=1)

# %%
x
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          1
# 1          1  80.0             0              1             1          1
# 2          0  49.0             0              0             1          1
# 3          0  79.0             1              0             1          2
# 4          1  81.0             0              0             1          1
# ...      ...   ...           ...            ...           ...        ...
# 4976       1  41.0             0              0             0          1
# 4977       1  40.0             0              0             1          1
# 4978       0  45.0             1              0             1          0
# 4979       1  40.0             0              0             1          1
# 4980       0  80.0             1              0             1          1
#
#       Residence_type  smoking_status  stroke
# 0                  1               1       1
# ...

# %%
y = df[['avg_glucose_level','bmi']]

# %%
y
# Out:
#       avg_glucose_level   bmi
# 0                228.69  36.6
# 1                105.92  32.5
# 2                171.23  34.4
# 3                174.12  24.0
# 4                186.21  29.0
# ...                 ...   ...
# 4976              70.15  29.8
# 4977             191.15  31.1
# 4978              95.02  31.8
# 4979              83.94  30.0
# 4980              83.75  29.1
#
# [4981 rows x 2 columns]

# %%
newy = minmax.fit_transform(y)

# %%
type(newy)
# Out:
# numpy.ndarray

# %%
y = pd.DataFrame(newy,columns=['avg_glucose_level','bmi'])

# %%
df = pd.concat([x,y],axis=1)

# %%
df
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          1
# 1          1  80.0             0              1             1          1
# 2          0  49.0             0              0             1          1
# 3          0  79.0             1              0             1          2
# 4          1  81.0             0              0             1          1
# ...      ...   ...           ...            ...           ...        ...
# 4976       1  41.0             0              0             0          1
# 4977       1  40.0             0              0             1          1
# 4978       0  45.0             1              0             1          0
# 4979       1  40.0             0              0             1          1
# 4980       0  80.0             1              0             1          1
#
#       Residence_type  smoking_status  stroke  avg_glucose_level       bmi
# ...

# %% [markdown]
# # machine learning models

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
x=df.drop(['stroke'],axis=1)
y = df['stroke']

# %%
x
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          1
# 1          1  80.0             0              1             1          1
# 2          0  49.0             0              0             1          1
# 3          0  79.0             1              0             1          2
# 4          1  81.0             0              0             1          1
# ...      ...   ...           ...            ...           ...        ...
# 4976       1  41.0             0              0             0          1
# 4977       1  40.0             0              0             1          1
# 4978       0  45.0             1              0             1          0
# 4979       1  40.0             0              0             1          1
# 4980       0  80.0             1              0             1          1
#
#       Residence_type  smoking_status  avg_glucose_level       bmi
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train)
# Out:
#       gender    age  hypertension  heart_disease  ever_married  work_type  \
# 1652       0  26.00             0              0             0          1
# 1609       0  27.00             0              0             1          1
# 166        1  54.00             0              0             1          0
# 2488       0   2.00             0              0             0          3
# 3337       0  69.00             1              0             1          1
# ...      ...    ...           ...            ...           ...        ...
# 4426       0  54.00             0              0             1          0
# 466        0  38.00             0              0             1          0
# 3092       1  13.00             0              0             0          1
# 3772       0   0.48             0              0             0          3
# 860        0  57.00             0              0             1          2
#
#       Residence_type  smoking_status  avg_glucose_level       bmi
# ...

# %%
#models prediction

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()

# %%
modelLR = LR.fit(x_train,y_train)
# Out:
# c:\Users\mauzu\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
y_predLR = modelLR.predict(x_test)

# %%
print('the accuracy score:', accuracy_score(y_predLR,y_test))
# Out:
# the accuracy score: 0.9458375125376128

# %%
#prediction

# %%
x
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          1
# 1          1  80.0             0              1             1          1
# 2          0  49.0             0              0             1          1
# 3          0  79.0             1              0             1          2
# 4          1  81.0             0              0             1          1
# ...      ...   ...           ...            ...           ...        ...
# 4976       1  41.0             0              0             0          1
# 4977       1  40.0             0              0             1          1
# 4978       0  45.0             1              0             1          0
# 4979       1  40.0             0              0             1          1
# 4980       0  80.0             1              0             1          1
#
#       Residence_type  smoking_status  avg_glucose_level       bmi
# ...

# %%
modelLR.predict([[1	,41.0	,0	,0	,0	,1	,0	,1	,0.069384	,0.452722]])
# Out:
# c:\Users\mauzu\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
modelLR.predict([[1,87.0,	1,	1,	1,	1,	1,	1,	0.801265,	0.647564]])
# Out:
# c:\Users\mauzu\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# Decisison tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT = DecisionTreeClassifier()

# %%
modelDT = DT.fit(x_train,y_train)
y_predDT = modelDT.predict(x_test)

# %%
print('the accuracy score of DT :', accuracy_score(y_predDT,y_test))
# Out:
# the accuracy score of DT : 0.917753259779338

# %%
# random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF = RandomForestClassifier()

# %%
modelRF = RF.fit(x_train,y_train)
y_predRF = modelRF.predict(x_test)

# %%
print('the accuracy score of RF:', accuracy_score(y_predRF,y_test))
# Out:
# the accuracy score of RF: 0.9428284854563691

# %%
# Navive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
GNB =GaussianNB()

# %%
ModelGNB = GNB.fit(x_train,y_train)
y_predGNB = ModelGNB.predict(x_test)

# %%
print('the accuracy score of RF:', accuracy_score(y_predGNB,y_test))
# Out:
# the accuracy score of RF: 0.8605817452357071

# %%
from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB()

# %%
modelMNB = MNB.fit(x_train,y_train)
y_predMNB = modelMNB.predict(x_test)

# %%
print('the accuracy score of RF:', accuracy_score(y_predMNB,y_test))
# Out:
# the accuracy score of RF: 0.9458375125376128

# %%
from sklearn.naive_bayes import  BernoulliNB
BNB = BernoulliNB()

# %%
modelBNB = BNB.fit(x_train,y_train)
y_predBNB = modelBNB.predict(x_test)

# %%
print('the accuracy score of RF:', accuracy_score(y_predBNB,y_test))
# Out:
# the accuracy score of RF: 0.9458375125376128

# %%
# boosters

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBC = GradientBoostingClassifier()

# %%
from sklearn.ensemble import AdaBoostClassifier
ABC = AdaBoostClassifier()

# %%
pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB 653.6 kB/s eta 0:03:12
#    ---------------------------------------- 0.2/124.9 MB 2.0 MB/s eta 0:01:01
#    ---------------------------------------- 0.6/124.9 MB 4.4 MB/s eta 0:00:29
#    ---------------------------------------- 0.9/124.9 MB 4.6 MB/s eta 0:00:27
#    ---------------------------------------- 1.1/124.9 MB 5.0 MB/s eta 0:00:25
#    ---------------------------------------- 1.1/124.9 MB 5.0 MB/s eta 0:00:25
#    ---------------------------------------- 1.1/124.9 MB 5.0 MB/s eta 0:00:25
#    ---------------------------------------- 1.1/124.9 MB 5.0 MB/s eta 0:00:25
#    ---------------------------------------- 1.1/124.9 MB 2.8 MB/s eta 0:00:45
#    ---------------------------------------- 1.3/124.9 MB 2.7 MB/s eta 0:00:47
# ...

# %%
import xgboost

# %%
from xgboost import XGBClassifier
XGB = XGBClassifier()

# %%
modelXGB = XGB.fit(x_train,y_train)
y_predXGB = modelXGB.predict(x_test)

# %%
print('the accuracy score of xgb:', accuracy_score(y_predXGB,y_test))
# Out:
# the accuracy score of xgb: 0.9388164493480441

# %%
modelXGB.predict([[1	,41.0	,0	,0	,0	,1	,0	,1	,0.069384	,0.452722]])
# Out:
# array([0])

# %%
modelXGB.predict([[1,87.0,	1,	1,	1,	1,	1,	1,	0.801265,	0.647564]])
# Out:
# array([1])

# %% [markdown]
# # summary

# %% [markdown]
# This project leverages machine learning techniques to predict the likelihood of a stroke based on various features such as age, gender, hypertension, heart disease, glucose levels, BMI, and lifestyle factors like smoking status and marital status. By analyzing and preprocessing a dataset (brain_stroke.csv), the project applies classification models to identify patterns and key indicators of stroke risk.

# %% [markdown]
# # conclusion

# %% [markdown]
# The implementation demonstrates the potential of artificial intelligence in healthcare, particularly for early detection and prevention of critical conditions like strokes. By employing robust machine learning algorithms and visualization techniques, the project highlights the importance of data-driven insights in identifying high-risk individuals and enabling timely intervention. The outcomes emphasize the significance of feature selection, data preprocessing, and model evaluation in achieving accurate predictions.
